# %%
import pandas as pd

# %% [markdown]
# # Cleaning Data

# %%
# Lire le fichier Excel
df = pd.read_excel('datastream.xlsx', sheet_name='Conf Board + Como + ISM + NAHB')

# %%
# Conversion de la colonne 'Name' en datetime
df['Name'] = pd.to_datetime(df['Name'])

# Conversion des autres colonnes en float
df.iloc[:, 1:] = df.iloc[:, 1:].astype(float)

# Renommage et mise en index
df.rename(columns={'Name': 'Date'}, inplace=True)
df.set_index('Date', inplace=True)
# Out:
# C:\Users\vadim\AppData\Local\Temp\ipykernel_11808\3957598011.py:5: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      66.0
# 1      68.0
# 2      76.0
# 3      67.0
# 4      55.0
#        ...
# 731    76.0
# 732    76.0
# 733    68.0
# 734    62.0
# 735    47.0
# Name: US ISM MANUFACTURERS SURVEY RESULTS: PRICES PAID - SAME VOLN, Length: 736, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.

# %%
# Assurez-vous que l'index de 'data' est de type datetime
df.index = pd.to_datetime(df.index)

# Créer un nouvel index avec le 15 de chaque mois en utilisant la fonction pd.date_range
new_index = pd.date_range(start=df.index.min().replace(day=1), end=df.index.max(), freq='MS') + pd.DateOffset(days=14)

# Réindexer 'data' pour aligner les indices au 15 de chaque mois
df.index = new_index

# Vérifier que les indices ont bien été modifiés
print(df.index)

# Maintenant, data et data_summerschool ont le même index, vous pouvez procéder aux calculs de corrélation
# Out:
# DatetimeIndex(['1963-12-15', '1964-01-15', '1964-02-15', '1964-03-15',
#                '1964-04-15', '1964-05-15', '1964-06-15', '1964-07-15',
#                '1964-08-15', '1964-09-15',
#                ...
#                '2024-06-15', '2024-07-15', '2024-08-15', '2024-09-15',
#                '2024-10-15', '2024-11-15', '2024-12-15', '2025-01-15',
#                '2025-02-15', '2025-03-15'],
#               dtype='datetime64[ns]', length=736, freq=None)

# %%
# Définir la plage de dates
start_date = "1985-01-01"
end_date =  "2024-08-31" # ou pd.Timestamp.today() mais on aurait des valeurs manquantes

# Filtrer le DataFrame sur la plage de dates
data = df.loc[start_date:end_date]

# Calculer le pourcentage de valeurs manquantes
missing_percent = data.isnull().mean() * 100

# Stocker les colonnes à supprimer et leur pourcentage de valeurs manquantes
removed_columns = {col: missing_percent[col] for col in data.columns if missing_percent[col] > 0}

# Supprimer les colonnes avec des valeurs manquantes
data = data.dropna(axis=1)

# Afficher un tableau avec les colonnes supprimées
removed_df = pd.DataFrame(list(removed_columns.items()), columns=["Colonne", "% Valeurs Manquantes"])
removed_df
# Out:
#                                                         Colonne  \
# 0           ICE BofA US High Yield 100 Index - Price Rate of RI
# 1           US ISM MANUFACTURERS SURVEY: SUPPLIER DELIVERY NADJ
# 2  US ISM MANUFACTURERS SURVEY: CUSTOMER INVENTORIES INDEX NADJ
# 3    US ISM MANUFACTURERS SURVEY: INVENTORIES INDEX(DISC.) NADJ
# 4    US ISM MANUFACTURERS SURVEY: SUPPLIER DELIVERY(DISC.) SADJ
# 5    US ISM MANUFACTURERS SURVEY: PRICES PAID INDEX(DISC.) SADJ
#
#    % Valeurs Manquantes
# 0             50.210084
# 1             68.067227
# 2             30.252101
# 3             31.932773
# 4             31.932773
# 5             54.621849

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
# Vérifier que le nombre de mois entre le premier et le dernier index est égal au nombre de lignes
num_months = (data.index[-1].year - data.index[0].year) * 12 + (data.index[-1].month - data.index[0].month + 1)
is_correct = num_months == len(data)
print(f"Nombre de mois: {num_months}, Nombre de lignes: {len(data)}, Vérification: {is_correct}")
# Out:
# Nombre de mois: 476, Nombre de lignes: 476, Vérification: True

# %%
data.shape
# Out:
# (476, 49)

# %% [markdown]
# # Correlation

# %%
data_summerschool = pd.read_excel('datastream.xlsx', sheet_name='SummerSchool')

data_summerschool.drop(columns=["USA (Acc_Slow)"], inplace=True)

# Supprimer la première ligne du DataFrame data_summerschool avec drop
data_summerschool = data_summerschool.drop(data_summerschool.index[0])

# Conversion de la colonne 'dates' en datetime
data_summerschool['dates'] = pd.to_datetime(data_summerschool['dates'])

# Conversion des autres colonnes en float
data_summerschool.iloc[:, 1:] = data_summerschool.iloc[:, 1:].astype(float)

# Mise en index
data_summerschool.set_index('dates', inplace=True)

data_summerschool.shape
# Out:
# (432, 70)

# %%
import difflib

# Faire correspondre les colonnes entre data et data_summerschool
cols_data = set(data.columns)
cols_summerschool = set(data_summerschool.columns)
matched_columns = {}
for col in cols_summerschool:
    match = difflib.get_close_matches(col, cols_data, n=1, cutoff=0.9)
    if match:
        matched_columns[col] = match[0]

#Etendre à la mano les derniers matchings
matched_columns['CRB BLS Spot Index (1967=100) - PRICE INDEX'] = "cmdty BLS Commodity Price Ind 'DEAD' - PRICE INDEX"
matched_columns['Gold Bullion LBM U$/Troy Ounce'] = 'Gold Bullion LBM $/t oz DELAY'
matched_columns["Crude Oil-WTI Spot Cushing U$/BBL - DS MID PRICE"] = 'Crude Oil-WTI Spot Cushing U$/BBL'
matched_columns['US ISM MANUFACTURERS SURVEY: PRICE PAID INDEX SADJ	'] = "US ISM MANUFACTURERS SURVEY RESULTS: PRICES PAID - SAME VOLN"

# Vérifier les correspondances trouvées
print("Correspondances trouvées :", len(matched_columns))

# Calculer la corrélation pour chaque variable appariée en alignant les tailles
correlations = []
for old_col, new_col in matched_columns.items():
    if old_col in data_summerschool.columns and new_col in data.columns:
        min_length = min(len(data_summerschool[old_col]), len(data[new_col]))
        correlation_value = data_summerschool[old_col].iloc[:min_length].corr(data[new_col].iloc[:min_length])
        correlations.append([old_col, new_col, correlation_value])

# Créer un DataFrame avec 3 colonnes
correlation_df = pd.DataFrame(correlations, columns=["Colonne Summerschool", "Colonne Data", "Corrélation"])

# Afficher les résultats
pd.set_option('display.max_colwidth', None)
# Trier le DataFrame par la colonne "Corrélation" de manière décroissante
correlation_df_sorted = correlation_df.sort_values(by="Corrélation", ascending=False)
correlation_df
# Out:
# Correspondances trouvées : 49
#                                                 Colonne Summerschool  \
# 0                                  US CONSUMER CONFIDENCE INDEX SADJ
# 1        US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY AUTO SADJ
# 2                                    S&P 500 COMPOSITE - PRICE INDEX
# 3      US CONSUMER CONFIDENCE IN 6 MONTHS-BUSINESS CONDITIONS BETTER
# 4          US INITIAL CLAIMS FOR UNEMPLOYMENT INSURANCE (BCI 5) VOLA
# 5             US CONSUMER CONFIDENCE CURRENTLY - JOBS PLENTIFUL SADJ
# 6         US CONSUMER CONFIDENCE IN 6 MONTHS - INCOME DECREASED SADJ
# 7              US CONSUMER CONFIDENCE INDEX - PRESENT SITUATION SADJ
# 8          US CONSUMER CONFIDENCE CURRENTLY - JOBS HARD TO FIND SADJ
# 9       US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY REFRIGERATOR
# 10   US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY AIR CONDITIONER
# 11   US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY ANY HOME SADJ
# 12  US CONSUMER CONFIDENCE CURRENTLY-BUSINESS CONDITIONS NORMAL SADJ
# 13                US ISM PURCHASING MANAGERS INDEX (MFG SURVEY) SADJ
# 14                  US CONSUMER CONFIDENCE INDEX - EXPECTATIONS SADJ
# 15   US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY NEW AUTO SADJ
# 16             US CONSUMER CONFIDENCE IN 6 MONTHS - INCOME SAME SADJ
# 17   US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY WASHING MACHINE
# 18     US CONSUMER CONFIDENCE CURRENTLY - JOBS NOT SO PLENTIFUL SADJ
# 19               US CONSUMER CONFIDENCE IN 6 MONTHS - JOBS SAME SADJ
# 20   US CONSUMER CONFIDENCE CURRENTLY - BUSINESS CONDITIONS BAD SADJ
# 21  US CONSUMER CONFIDENCE IN 6 MONTHS-BUSINESS CONDITIONS SAME SADJ
# 22     US NAHB MARKET SURVEY: TRAFFIC OF PROSPECTIVE NEW HOME BUYERS
# 23                US ISM MANUFACTURERS SURVEY: PRODUCTION INDEX SADJ
# 24     US NAHB MARKET SURVEY: NEW SINGLE FAMILY HOME SALES-CURRENTLY
# 25       US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY HOME SADJ
# 26    US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY AUTO UNCERTAIN
# 27     US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY CLOTHES DRYER
# 28  US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY USED AUTO SADJ
# 29                US ISM MANUFACTURERS SURVEY: NEW ORDERS INDEX SADJ
# 30      US CONSUMER CONFIDENCE IN 6 MONTHS-BUSINESS CONDITIONS WORSE
# 31  US CONSUMER CONFIDENCE CURRENTLY - BUSINESS CONDITIONS GOOD SADJ
# 32      US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY RANGE SADJ
# 33  US NAHB MARKET SURVEY: NEW SINGLE FAMILY HOME SALES-IN NEXT 6 MO
# 34              US CONSUMER CONFIDENCE IN 6 MONTHS - JOBS FEWER SADJ
# 35     US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY LIVED IN HOME
# 36  US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY MAJOR APPLIANCES
# 37   US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY NEW HOME SADJ
# 38               US CONSUMER CONFIDENCE IN 6 MONTHS - JOBS MORE SADJ
# 39        US CONSUMER CONFIDENCE IN 6 MONTHS - INCOME INCREASED SADJ
# 40     US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY CARPET SADJ
# 41     US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY TV SET SADJ
# 42    US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY VACUUM CLEANER
# 43     US NATIONAL ASSOCIATION OF HOME BUILDERS HOUSING MARKET INDEX
# 44                US ISM MANUFACTURERS SURVEY: EMPLOYMENT INDEX SADJ
# 45                       CRB BLS Spot Index (1967=100) - PRICE INDEX
# 46                                    Gold Bullion LBM U$/Troy Ounce
# 47                  Crude Oil-WTI Spot Cushing U$/BBL - DS MID PRICE
#
#                                                         Colonne Data  \
# 0                                  US CONSUMER CONFIDENCE INDEX SADJ
# 1        US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY AUTO SADJ
# 2                                    S&P 500 COMPOSITE - PRICE INDEX
# 3      US CONSUMER CONFIDENCE IN 6 MONTHS-BUSINESS CONDITIONS BETTER
# 4          US INITIAL CLAIMS FOR UNEMPLOYMENT INSURANCE (BCI 5) VOLA
# 5             US CONSUMER CONFIDENCE CURRENTLY - JOBS PLENTIFUL SADJ
# 6         US CONSUMER CONFIDENCE IN 6 MONTHS - INCOME DECREASED SADJ
# 7              US CONSUMER CONFIDENCE INDEX - PRESENT SITUATION SADJ
# 8          US CONSUMER CONFIDENCE CURRENTLY - JOBS HARD TO FIND SADJ
# 9       US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY REFRIGERATOR
# 10   US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY AIR CONDITIONER
# 11   US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY ANY HOME SADJ
# 12  US CONSUMER CONFIDENCE CURRENTLY-BUSINESS CONDITIONS NORMAL SADJ
# 13                US ISM PURCHASING MANAGERS INDEX (MFG SURVEY) SADJ
# 14                  US CONSUMER CONFIDENCE INDEX - EXPECTATIONS SADJ
# 15   US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY NEW AUTO SADJ
# 16             US CONSUMER CONFIDENCE IN 6 MONTHS - INCOME SAME SADJ
# 17   US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY WASHING MACHINE
# 18     US CONSUMER CONFIDENCE CURRENTLY - JOBS NOT SO PLENTIFUL SADJ
# 19               US CONSUMER CONFIDENCE IN 6 MONTHS - JOBS SAME SADJ
# 20   US CONSUMER CONFIDENCE CURRENTLY - BUSINESS CONDITIONS BAD SADJ
# 21  US CONSUMER CONFIDENCE IN 6 MONTHS-BUSINESS CONDITIONS SAME SADJ
# 22     US NAHB MARKET SURVEY: TRAFFIC OF PROSPECTIVE NEW HOME BUYERS
# 23                US ISM MANUFACTURERS SURVEY: PRODUCTION INDEX SADJ
# 24     US NAHB MARKET SURVEY: NEW SINGLE FAMILY HOME SALES-CURRENTLY
# 25       US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY HOME SADJ
# 26    US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY AUTO UNCERTAIN
# 27     US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY CLOTHES DRYER
# 28  US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY USED AUTO SADJ
# 29                US ISM MANUFACTURERS SURVEY: NEW ORDERS INDEX SADJ
# 30      US CONSUMER CONFIDENCE IN 6 MONTHS-BUSINESS CONDITIONS WORSE
# 31  US CONSUMER CONFIDENCE CURRENTLY - BUSINESS CONDITIONS GOOD SADJ
# 32      US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY RANGE SADJ
# 33  US NAHB MARKET SURVEY: NEW SINGLE FAMILY HOME SALES-IN NEXT 6 MO
# 34              US CONSUMER CONFIDENCE IN 6 MONTHS - JOBS FEWER SADJ
# 35     US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY LIVED IN HOME
# 36  US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY MAJOR APPL( SADJ
# 37   US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY NEW HOME SADJ
# 38               US CONSUMER CONFIDENCE IN 6 MONTHS - JOBS MORE SADJ
# 39        US CONSUMER CONFIDENCE IN 6 MONTHS - INCOME INCREASED SADJ
# 40     US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY CARPET SADJ
# 41     US CONSUMER CONFIDENCE IN 6 MONTHS - PLANS TO BUY TV SET SADJ
# 42    US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY VACUUM CLEANER
# 43     US NATIONAL ASSOCIATION OF HOME BUILDERS HOUSING MARKET INDEX
# 44                US ISM MANUFACTURERS SURVEY: EMPLOYMENT INDEX SADJ
# 45                cmdty BLS Commodity Price Ind 'DEAD' - PRICE INDEX
# 46                                     Gold Bullion LBM $/t oz DELAY
# 47                                 Crude Oil-WTI Spot Cushing U$/BBL
#
#     Corrélation
# 0      0.999922
# 1      1.000000
# 2      0.928458
# 3      1.000000
# 4     -0.640356
# 5      1.000000
# 6      1.000000
# 7      1.000000
# 8      1.000000
# 9      1.000000
# 10     1.000000
# 11     1.000000
# 12     1.000000
# 13     0.999987
# 14     1.000000
# 15     1.000000
# 16     1.000000
# 17     1.000000
# 18     1.000000
# 19     1.000000
# 20     1.000000
# 21     1.000000
# 22     1.000000
# 23     0.999901
# 24     1.000000
# 25     1.000000
# 26     0.994581
# 27     1.000000
# 28     1.000000
# 29     0.999932
# 30     1.000000
# 31     1.000000
# 32     1.000000
# 33     1.000000
# 34     1.000000
# 35     1.000000
# 36     1.000000
# 37     1.000000
# 38     1.000000
# 39     1.000000
# 40     1.000000
# 41     1.000000
# 42     1.000000
# 43     1.000000
# 44     0.999969
# 45     0.993678
# 46     0.982110
# 47     0.697599

# %% [markdown]
# On valide toutes les variables. Meme si S&P 500 n'est pas à 1, cela ne veut pas dire qu'il a été révisé mais plutôt que les entreprises qu'il track changent. Pour Crude Oil, ce n'est pas la même variable mais je pense que crude oil n'est pas révisée non plus ; autant la garder pour le moment quitte à la supprimer plus tard.

# %%
'''
#Toutes les variables de data ne sont pas matchées (il en manque 2) et certaines sont matchées plus d'une fois. Il faut donc revoir le matching

# Compter le nombre d'apparitions des noms de colonnes dans "Colonne Data" (new_col)
count_new_cols = correlation_df.groupby('Colonne Data').size().reset_index(name='Nombre d\'apparitions')

# Filtrer les colonnes qui apparaissent plus d'une fois
count_new_cols = count_new_cols[count_new_cols['Nombre d\'apparitions'] > 1]

# Afficher le résultat
count_new_cols


'''


correlation_df['Colonne Data'].nunique()
# Out:
# 48

# %%
# Colonnes non appariées dans data et data_summerschool
unmatched_data_cols = list(set(data.columns) - set(matched_columns.values()))  # Colonnes de data non appariées
unmatched_summerschool_cols = list(set(data_summerschool.columns) - set(matched_columns.keys()))  # Colonnes de data_summerschool non appariées

# Compléter la liste la plus courte avec des NaN pour équilibrer la longueur
max_length = max(len(unmatched_data_cols), len(unmatched_summerschool_cols))

unmatched_data_cols.extend([None] * (max_length - len(unmatched_data_cols)))
unmatched_summerschool_cols.extend([None] * (max_length - len(unmatched_summerschool_cols)))

# Créer un DataFrame avec les résultats
unmatched_df = pd.DataFrame({
    'Colonnes SummerSchool (non appariées)': unmatched_summerschool_cols,
    'Colonnes Data (non appariées)': unmatched_data_cols
    
})

# Afficher le DataFrame
unmatched_df
# Out:
#                         Colonnes SummerSchool (non appariées)  \
# 0                                                   spread102
# 1         US ISM MANUFACTURERS SURVEY: INVENTORIES INDEX NADJ
# 2                                                    spread52
# 3                                                  spread103m
# 4   US ISM MANUFACTURERS SURVEY: SUPPLIER DELIVERY INDEX SADJ
# 5                                                       HY-US
# 6                                                   spread23m
# 7                                                    spread21
# 8                                                      BAA-US
# 9                                                   spread13m
# 10                                                      AA-US
# 11                                                     AAA-US
# 12                                                       A-HY
# 13                                                  spread53m
# 14                                                  spread105
# 15                                                      AA-HY
# 16                                                  spread63m
# 17         US ISM MANUFACTURERS SURVEY: PRICE PAID INDEX SADJ
# 18                                                     AAA-HY
# 19    ICE BofAML US High Yield 100 Index - Yld to Mat convent
# 20                                                       A-US
# 21                                                     BAA-HY
#
#    Colonnes Data (non appariées)
# 0                           None
# 1                           None
# 2                           None
# 3                           None
# 4                           None
# 5                           None
# 6                           None
# 7                           None
# 8                           None
# 9                           None
# 10                          None
# 11                          None
# 12                          None
# 13                          None
# 14                          None
# 15                          None
# 16                          None
# 17                          None
# 18                          None
# 19                          None
# 20                          None
# 21                          None

# %% [markdown]
# Certains consensus survey semblent ne plus être mises à jour. Pour le reste des données il faudra les chercher sur FRED

# %% [markdown]
# # CSV output

# %%
len(data.columns) == data.columns.nunique()
# Out:
# True

# %%
data
# Out:
#             S&P 500 COMPOSITE - PRICE INDEX  \
# 1985-01-15                           179.63
# 1985-02-15                           181.18
# 1985-03-15                           180.66
# 1985-04-15                           179.83
# 1985-05-15                           189.55
# ...                                     ...
# 2024-04-15                          5035.69
# 2024-05-15                          5277.51
# 2024-06-15                          5460.48
# 2024-07-15                          5522.30
# 2024-08-15                          5648.40
#
#             cmdty BLS Commodity Price Ind 'DEAD' - PRICE INDEX  \
# 1985-01-15                                              256.90
# 1985-02-15                                              251.90
# 1985-03-15                                              256.80
# 1985-04-15                                              254.10
# 1985-05-15                                              246.80
# ...                                                        ...
# 2024-04-15                                              399.23
# 2024-05-15                                              399.23
# 2024-06-15                                              399.23
# 2024-07-15                                              399.23
# 2024-08-15                                              399.23
#
#             Gold Bullion LBM $/t oz DELAY  Crude Oil-WTI Spot Cushing U$/BBL  \
# 1985-01-15                         306.75                              26.35
# 1985-02-15                         288.75                              28.00
# 1985-03-15                         330.00                              28.30
# 1985-04-15                         321.00                              27.60
# 1985-05-15                         316.00                              27.85
# ...                                   ...                                ...
# 2024-04-15                        2296.49                              83.49
# 2024-05-15                        2330.65                              77.97
# 2024-06-15                        2326.30                              82.83
# 2024-07-15                        2421.91                              79.36
# 2024-08-15                        2505.28                              74.52
#
#             US INITIAL CLAIMS FOR UNEMPLOYMENT INSURANCE (BCI 5) VOLA  \
# 1985-01-15                                                      375.0
# 1985-02-15                                                      388.8
# 1985-03-15                                                      382.5
# 1985-04-15                                                      398.3
# 1985-05-15                                                      393.5
# ...                                                               ...
# 2024-04-15                                                      210.3
# 2024-05-15                                                      222.3
# 2024-06-15                                                      238.8
# 2024-07-15                                                      238.3
# 2024-08-15                                                      230.3
#
#             US NAHB MARKET SURVEY: NEW SINGLE FAMILY HOME SALES-CURRENTLY  \
# 1985-01-15                                                           50.0
# 1985-02-15                                                           61.0
# 1985-03-15                                                           56.0
# 1985-04-15                                                           51.0
# 1985-05-15                                                           53.0
# ...                                                                   ...
# 2024-04-15                                                           57.0
# 2024-05-15                                                           51.0
# 2024-06-15                                                           48.0
# 2024-07-15                                                           46.0
# 2024-08-15                                                           44.0
#
#             US CONSUMER CONFIDENCE INDEX SADJ  \
# 1985-01-15                              102.0
# 1985-02-15                              103.1
# 1985-03-15                               96.1
# 1985-04-15                              104.4
# 1985-05-15                               99.6
# ...                                       ...
# 2024-04-15                               97.5
# 2024-05-15                              101.3
# 2024-06-15                               97.8
# 2024-07-15                              101.9
# 2024-08-15                              105.6
#
#             US CONSUMER CONFIDENCE INDEX - EXPECTATIONS SADJ  \
# 1985-01-15                                             102.5
# 1985-02-15                                             103.9
# 1985-03-15                                              95.9
# 1985-04-15                                             105.1
# 1985-05-15                                              99.6
# ...                                                      ...
# 2024-04-15                                              68.8
# 2024-05-15                                              74.9
# 2024-06-15                                              72.8
# 2024-07-15                                              78.2
# 2024-08-15                                              86.3
#
#             US CONSUMER CONFIDENCE INDEX - PRESENT SITUATION SADJ  \
# 1985-01-15                                                  101.2
# 1985-02-15                                                  102.0
# 1985-03-15                                                   96.5
# 1985-04-15                                                  103.5
# 1985-05-15                                                   99.6
# ...                                                           ...
# 2024-04-15                                                  140.6
# 2024-05-15                                                  140.8
# 2024-06-15                                                  135.3
# 2024-07-15                                                  133.6
# 2024-08-15                                                  134.6
#
#             US CONSUMER CONFIDENCE CURRENTLY - JOBS PLENTIFUL SADJ  ...  \
# 1985-01-15                                                    19.6  ...
# 1985-02-15                                                    19.7  ...
# 1985-03-15                                                    18.2  ...
# 1985-04-15                                                    19.1  ...
# 1985-05-15                                                    19.3  ...
# ...                                                            ...  ...
# 2024-04-15                                                    38.4  ...
# 2024-05-15                                                    37.0  ...
# 2024-06-15                                                    35.5  ...
# 2024-07-15                                                    34.1  ...
# 2024-08-15                                                    32.7  ...
#
#             US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY VACUUM CLEANER  \
# 1985-01-15                                                             5.2
# 1985-02-15                                                             5.0
# 1985-03-15                                                             4.6
# 1985-04-15                                                             4.2
# 1985-05-15                                                             3.9
# ...                                                                    ...
# 2024-04-15                                                             7.4
# 2024-05-15                                                             8.8
# 2024-06-15                                                             8.5
# 2024-07-15                                                             8.5
# 2024-08-15                                                             8.6
#
#             US CONSUMER CONFIDENCE IN 6 MONTHS-PLANS TO BUY WASHING MACHINE  \
# 1985-01-15                                                              3.8
# 1985-02-15                                                              3.6
# 1985-03-15                                                              3.8
# 1985-04-15                                                              4.5
# 1985-05-15                                                              3.0
# ...                                                                     ...
# 2024-04-15                                                              5.6
# 2024-05-15                                                              5.6
# 2024-06-15                                                              6.5
# 2024-07-15                                                              5.9
# 2024-08-15                                                              6.0
#
#             US NATIONAL ASSOCIATION OF HOME BUILDERS HOUSING MARKET INDEX  \
# 1985-01-15                                                           50.0
# 1985-02-15                                                           58.0
# 1985-03-15                                                           54.0
# 1985-04-15                                                           49.0
# 1985-05-15                                                           51.0
# ...                                                                   ...
# 2024-04-15                                                           51.0
# 2024-05-15                                                           45.0
# 2024-06-15                                                           43.0
# 2024-07-15                                                           41.0
# 2024-08-15                                                           39.0
#
#             US NAHB MARKET SURVEY: NEW SINGLE FAMILY HOME SALES-IN NEXT 6 MO  \
# 1985-01-15                                                              59.0
# 1985-02-15                                                              64.0
# 1985-03-15                                                              57.0
# 1985-04-15                                                              56.0
# 1985-05-15                                                              58.0
# ...                                                                      ...
# 2024-04-15                                                              60.0
# 2024-05-15                                                              51.0
# 2024-06-15                                                              47.0
# 2024-07-15                                                              48.0
# 2024-08-15                                                              49.0
#
#             US NAHB MARKET SURVEY: TRAFFIC OF PROSPECTIVE NEW HOME BUYERS  \
# 1985-01-15                                                           44.0
# 1985-02-15                                                           48.0
# 1985-03-15                                                           48.0
# 1985-04-15                                                           41.0
# 1985-05-15                                                           42.0
# ...                                                                   ...
# 2024-04-15                                                           34.0
# 2024-05-15                                                           30.0
# 2024-06-15                                                           28.0
# 2024-07-15                                                           27.0
# 2024-08-15                                                           25.0
#
#             US ISM PURCHASING MANAGERS INDEX (MFG SURVEY) SADJ  \
# 1985-01-15                                                50.3
# 1985-02-15                                                49.9
# 1985-03-15                                                47.8
# 1985-04-15                                                48.2
# 1985-05-15                                                47.1
# ...                                                        ...
# 2024-04-15                                                48.8
# 2024-05-15                                                48.5
# 2024-06-15                                                48.3
# 2024-07-15                                                47.0
# 2024-08-15                                                47.5
#
#             US ISM MANUFACTURERS SURVEY: NEW ORDERS INDEX SADJ  \
# 1985-01-15                                                51.8
# 1985-02-15                                                51.8
# 1985-03-15                                                49.1
# 1985-04-15                                                51.3
# 1985-05-15                                                49.5
# ...                                                        ...
# 2024-04-15                                                48.7
# 2024-05-15                                                46.3
# 2024-06-15                                                48.9
# 2024-07-15                                                47.6
# 2024-08-15                                                45.6
#
#             US ISM MANUFACTURERS SURVEY RESULTS: PRICES PAID - SAME VOLN  \
# 1985-01-15                                                          66.0
# 1985-02-15                                                          75.0
# 1985-03-15                                                          74.0
# 1985-04-15                                                          79.0
# 1985-05-15                                                          76.0
# ...                                                                  ...
# 2024-04-15                                                          60.0
# 2024-05-15                                                          63.0
# 2024-06-15                                                          64.0
# 2024-07-15                                                          61.0
# 2024-08-15                                                          65.0
#
#             US ISM MANUFACTURERS SURVEY: PRODUCTION INDEX SADJ  \
# 1985-01-15                                                54.9
# 1985-02-15                                                54.2
# 1985-03-15                                                51.2
# 1985-04-15                                                51.6
# 1985-05-15                                                51.9
# ...                                                        ...
# 2024-04-15                                                50.7
# 2024-05-15                                                49.6
# 2024-06-15                                                48.7
# 2024-07-15                                                46.6
# 2024-08-15                                                45.6
#
#             US ISM MANUFACTURERS SURVEY: EMPLOYMENT INDEX SADJ
# 1985-01-15                                                44.4
# 1985-02-15                                                45.2
# 1985-03-15                                                44.2
# 1985-04-15                                                43.2
# 1985-05-15                                                40.4
# ...                                                        ...
# 2024-04-15                                                48.2
# 2024-05-15                                                50.4
# 2024-06-15                                                48.4
# 2024-07-15                                                43.6
# 2024-08-15                                                45.8
#
# [476 rows x 49 columns]

# %%
data.to_csv("data.csv", index=True)
